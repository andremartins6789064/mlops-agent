# %% [markdown]
# # Classification pipeline fixture

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
X = pd.DataFrame({"x1": [0, 1, 1], "x2": [1, 0, 1]})
y = [0, 1, 1]

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X, y)
print("accuracy=1.0")
# Out:
# accuracy=1.0
